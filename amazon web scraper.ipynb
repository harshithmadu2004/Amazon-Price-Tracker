# %%
from bs4 import BeautifulSoup
import requests
import time
import datetime

import smtplib

def check_price():
    URL = 'https://www.amazon.in/DSC-Gods-English-Willow-Cricket/dp/B0FWBWWP8Z/ref=sr_1_7?crid=3T4YAEBN57L8Y&dib=eyJ2IjoiMSJ9.TVJQ_3QiBXzz2LuxC7PUvZ6Y_W7Ww1eI4hQ6t0KGDLzHYIuwvxm7TXqInBc6oLXtk00Ln6URJeWUUmYeSFMv45kkeT-ac59GEl_rhKp7PTq13-ix-xOoJGKll_TbtqxcPEKRMogUkSVHlFaUXx1L5xfnjsBYWgPlPqpV1rRg5EFjvT7kG5_o1s6enu2n9vYfZopn_os9jHX9-ckba1AQ__wpIRedZYMKR5f6lxT5XAa0S7VM6c_096lU0eK1ivGZ60OnJ-yiECufnKg4utmDyVroRtFbsl_ikytvntuXaQU.0Jq2wOJrr_80l_yQhYJX7Kob1LubnJeSv2pe2R_K_Yo&dib_tag=se&keywords=cricket%2Bbat&qid=1762955900&sprefix=cricket%2Bbat%2Caps%2C248&sr=8-7&th=1'

    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

    page = requests.get(URL, headers=headers)

    soup1 = BeautifulSoup(page.content, "html.parser")

    soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

    title = soup2.find(id='productTitle').get_text()

    price = soup2.find(id='corePrice_desktop').get_text()

    price = price.strip()[1:]
    title = title.strip()

    import datetime

    today = datetime.date.today()
    
    import csv 

    header = ['Title', 'Price', 'Date']
    data = [title, price, today]

    with open('AmazonWebScraperDataset.csv', 'a+', newline='', encoding='UTF8') as f:
        writer = csv.writer(f)
        writer.writerow(data)
while(True):
 check_price()
 time.sleep(86400)

df = pd.read_csv(r'C:\Users\hars\AmazonWebScraperDataset.csv')

print(df)

def send_mail():
    server = smtplib.SMTP_SSL('smtp.gmail.com',465)
    server.ehlo()
    #server.starttls()
    server.ehlo()
    server.login('harshith2004m@gmail.com','xxxxxxxxxxxxxx')
    
    subject = "The cricket bat you want is below $15! Now is your chance to buy!"
    body = "harshith, This is the moment we have been waiting for. Now is your chance to pick up the shirt of your dreams. Don't mess it up! Link here: https://www.amazon.com/Funny-Data-Systems-Business-Analyst/dp/B07FNW9FGJ/ref=sr_1_3?dchild=1&keywords=data+analyst+tshirt&qid=1626655184&sr=8-3"
   
    msg = f"Subject: {subject}\n\n{body}"
    
    server.sendmail(
        'harshith2004m@gmail.com',
        msg
     
    )
